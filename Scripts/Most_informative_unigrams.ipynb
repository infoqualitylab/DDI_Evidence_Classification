# %%
#READ DATA FROM PREPROCESSED FILE
import pandas as pd
#CHANGE THE PATH TO THE FOLDER WHERE YOU STORE DATA
df = pd.read_csv('/Users/phuong/Documents/JBI_paper/Data_files/Main_Data/All_Papers_Preprocessed.csv',encoding ='latin1')
df.head()
# Out:
#        PMID                                      Article Title  \
# 0   8646822  A kinetic and dynamic study of oral alprazolam...
# 1   8453848  A potentially hazardous interaction between er...
# 2  23210726  A semi-mechanistic absorption model to evaluat...
# 3  11936570  A study of the interaction potential of azithr...
# 4   1387301  Absolute bioavailability of clarithromycin aft...
#
#                                             Abstract  \
# 0  To assess the possible involvement of CYP3A4 i...
# 1  Interaction between erythromycin and midazolam...
# 2  The aim of this study was to develop a PK/PD m...
# 3  Atorvastatin is a common option among the HMG-...
# 4  The absolute bioavailability of clarithromycin...
#
#                                     Publication Type  \
# 0  Clinical Trial ;Journal Article ;Randomized Co...
# 1  Clinical Trial ;Journal Article ;Randomized Co...
# 2  Journal Article ;Randomized Controlled Trial ;...
# 3  Clinical Trial ;Clinical Trial, Phase I ;Compa...
# 4  Clinical Trial ;Comparative Study ;Journal Art...
#
#                                      Methods Section         First Label  \
# 0  methods subjects twelve unrelated healthy male...  DDI Clinical Trial
# 1  material and methods study design orally admin...  DDI Clinical Trial
# 2  methods ten healthy male volunteers randomized...  DDI Clinical Trial
# 3  materials and methods this randomized open lab...  DDI Clinical Trial
# 4  clarithromycin new 14 membered macrolide antim...            PK Trial
#
#                                  Second Label  \
# 0                      RCT DDI Clinical Trial
# 1                      RCT DDI Clinical Trial
# 2                      RCT DDI Clinical Trial
# 3                      RCT DDI Clinical Trial
# 4  Non-polymorphic enzyme/transport PK Trial
#
#                                   Third Label
# 0                      RCT DDI Clinical Trial
# 1                      RCT DDI Clinical Trial
# 2                      RCT DDI Clinical Trial
# 3                      RCT DDI Clinical Trial
# 4  Non-polymorphic enzyme/transport PK Trial

# %%
#GENERATED LABELS FOR THE DATA
from io import StringIO

col = ['Article Title','Abstract','Methods Section','First Label','Second Label',"Third Label"]
df = df[col]

#generate categorize_id level 1 based on First Label
df.columns = ['Article Title','Abstract','Methods Section','First Label','Second Label',"Third Label"]
df['category_id_1'] = df['First Label'].factorize()[0]
category_id_df = df[['First Label', 'category_id_1']].drop_duplicates().sort_values('category_id_1')
category_to_id = dict(category_id_df.values)
id_to_category = dict(category_id_df[['category_id_1', 'First Label']].values)

#generate categorize_id level 2 based on Second Label
df['category_id_2'] = df['Second Label'].factorize()[0]
category_id_df_2 = df[['Second Label', 'category_id_2']].drop_duplicates().sort_values('category_id_2')
category_to_id_2 = dict(category_id_df_2.values)
id_to_category_2 = dict(category_id_df_2[['category_id_2', 'Second Label']].values)

#generate categorize_id level 3 based on Second Label
df['category_id_3'] = df['Third Label'].factorize()[0]
category_id_df_3 = df[['Third Label', 'category_id_3']].drop_duplicates().sort_values('category_id_3')
category_to_id_3 = dict(category_id_df_3.values)
id_to_category_3 = dict(category_id_df_3[['category_id_3', 'Third Label']].values)

df.head(100)
# Out:
#                                         Article Title  \
# 0   A kinetic and dynamic study of oral alprazolam...
# 1   A potentially hazardous interaction between er...
# 2   A semi-mechanistic absorption model to evaluat...
# 3   A study of the interaction potential of azithr...
# 4   Absolute bioavailability of clarithromycin aft...
# 5   Absolute bioavailability of oral immediate and...
# 6   Absolute oral bioavailability of rosuvastatin ...
# 7   Amiodarone interacts with simvastatin but not ...
# 8   An assessment of drug-drug interactions: the e...
# 9   Assessing the clinical significance of botanic...
# 10  Atomoxetine hydrochloride: clinical drug-drug ...
# 11  Carbamazepine but not valproate induces buprop...
# 12  Celecoxib inhibits metabolism of cytochrome P4...
# 13  Change from the CYP2D6 extensive metabolizer t...
# 14         Cimetidine interaction with amitriptyline.
# 15  Cimetidine interaction with imipramine and nor...
# 16  Clarithromycin pharmacokinetics in healthy you...
# 17  Coadministration of nefazodone and desipramine...
# 18  Coadministration of short-term zolpidem with s...
# 19  Comparative CYP3A4 inhibitory effects of venla...
# 20  Comparative pharmacokinetic interaction profil...
# 21  Comparison of midazolam and simvastatin as cyt...
# 22  Comparison of the pharmacokinetics of venlafax...
# 23  Comparison of verapamil, diltiazem, and labeta...
# 24  Concomitant use of mirtazapine and cimetidine:...
# 25  Contributions of CYP2D6, CYP2C9 and CYP2C19 to...
# 26  CYP2D6 genotype in relation to perphenazine co...
# 27  CYP2D6 inhibition by selective serotonin reupt...
# 28  Differential time course of cytochrome P450 2D...
# 29  Diltiazem enhances the effects of triazolam by...
# ..                                                ...
# 70  Enantioselective disposition of lansoprazole i...
# 71  Erythromycin and verapamil considerably increa...
# 72  Erythromycin coadministration increases plasma...
# 73  Exposure of atorvastatin is unchanged but lact...
# 74  Fluoxetine impairs the CYP2D6-mediated metabol...
# 75  Fluvoxamine inhibits the CYP2C9 catalyzed biot...
# 76  Griseofulvin and fluvoxamine interactions with...
# 77  Identification of a single time-point for plas...
# 78  Imipramine-cimetidine interaction: impairment ...
# 79  In vitro and in vivo evaluations of cytochrome...
# 80  In-vitro and in-vivo evaluation of the drug-dr...
# 81  Influence of fluoxetine on olanzapine pharmaco...
# 82  Influence of OATP1B1 genotype on the pharmacok...
# 83  Influence of SLCO1B1 polymorphisms on the drug...
# 84  Inhibition by paroxetine of desipramine metabo...
# 85        Inhibition of CYP2D6 activity by bupropion.
# 86  Inhibition of cytochrome P4502D6 activity with...
# 87  Inhibition of triazolam clearance by macrolide...
# 88  Introduction of a composite parameter to the p...
# 89  Itraconazole alters the pharmacokinetics of at...
# 90  Itraconazole drastically increases plasma conc...
# 91  Ketoconazole inhibition of triazolam and alpra...
# 92  Kinetic and dynamic interaction study of zolpi...
# 93  Lack of effect of a single dose of ketoconazol...
# 94  Lack of effect of ketoconazole on the pharmaco...
# 95  Lack of interaction between citalopram and the...
# 96  Lack of interaction between nefazodone and cim...
# 97  Lack of interaction between ramipril and simva...
# 98  Lack of pharmacokinetic interaction of mipomer...
# 99  Lipid lowering therapy with fluvastatin and pr...
#
#                                              Abstract  \
# 0   To assess the possible involvement of CYP3A4 i...
# 1   Interaction between erythromycin and midazolam...
# 2   The aim of this study was to develop a PK/PD m...
# 3   Atorvastatin is a common option among the HMG-...
# 4   The absolute bioavailability of clarithromycin...
# 5   The present study was conducted with the aim o...
# 6   Rosuvastatin is a 3-hydroxy-3-methylglutaryl c...
# 7   The aim of this study was to determine the inf...
# 8   A number of antidepressants inhibit the activi...
# 9   Phytochemical-mediated modulation of cytochrom...
# 10  In the studies reported here, the ability of a...
# 11  Bupropion (BUP) may be less likely than other ...
# 12  In vitro data have shown that celecoxib inhibi...
# 13  Some data indicate that bupropion inhibits the...
# 14  The interaction of cimetidine with amitriptyli...
# 15  The interaction between cimetidine and two tri...
# 16  The pharmacokinetics of clarithromycin and its...
# 17  To determine the potential for pharmacokinetic...
# 18  This study was undertaken to determine whether...
# 19  An antidepressant for use in the patient recei...
# 20  Three-hydroxy-3-methylglutaryl coenzyme-A redu...
# 21  Our objective was to compare simvastatin with ...
# 22  The goal of this study was to evaluate the imp...
# 23  Twelve healthy male subjects completed this ra...
# 24  The objective of this study was to examine the...
# 25  In-vitro data indicated a contribution of cyto...
# 26  Hyperprolactinemia is a common side effect of ...
# 27  To assess the correlation between plasma conce...
# 28  The selective serotonin reuptake inhibitors (S...
# 29  Triazolam is metabolized by CYP3A4. Diltiazem ...
# ..                                                ...
# 70  Lansoprazole is affected by polymorphism of CY...
# 71  To study the effects of erythromycin and verap...
# 72  The effect of erythromycin on the pharmacokine...
# 73  The most serious side effect from statin treat...
# 74  To determine the effect of 20 mg/day fluoxetin...
# 75  Our objective was to examine the interaction b...
# 76  Theophylline is predominantly metabolized by c...
# 77  The objective of this study was to identify a ...
# 78  Six healthy volunteers each received imipramin...
# 79  To determine whether duloxetine is a substrate...
# 80  The drug-drug interaction between fluvoxamine ...
# 81  Conventional antidepressant treatment fails fo...
# 82  This study was carried out to determine whethe...
# 83  The authors investigated whether SLCO1B1 polym...
# 84  Nine extensive metabolizers (EMs) and eight po...
# 85  The purpose of this study was to assess the ef...
# 86  The ultrarapid metabolizer phenotype of the cy...
# 87  Macrolide antimicrobial agents may impair hepa...
# 88  Venlafaxine is a structurally novel, nontricyc...
# 89  3-Hydroxy-3-methylglutaryl coenzyme A reductas...
# 90  Lovastatin is a cholesterol-lowering drug that...
# 91  Kinetic and dynamic consequences of metabolic ...
# 92  Azole antifungal agents may impair hepatic cle...
# 93  To determine whether the pharmacokinetics of t...
# 94  To examine in vivo the effect of ketoconazole ...
# 95  To determine the effect of the selective serot...
# 96  The steady-state pharmacokinetic interaction b...
# 97  Twenty two healthy males participated in a ran...
# 98  Mipomersen sodium (ISIS 301012) is a 20-mer ph...
# 99  Lipoprotein disorders in HIV-positive patients...
#
#                                       Methods Section         First Label  \
# 0   methods subjects twelve unrelated healthy male...  DDI Clinical Trial
# 1   material and methods study design orally admin...  DDI Clinical Trial
# 2   methods ten healthy male volunteers randomized...  DDI Clinical Trial
# 3   materials and methods this randomized open lab...  DDI Clinical Trial
# 4   clarithromycin new 14 membered macrolide antim...            PK Trial
# 5   materials methods the study performed accordan...            PK Trial
# 6   subjects and methods inclusion exclusion crite...            PK Trial
# 7   methods subjects twelve white occidental healt...  DDI Clinical Trial
# 8   materials methods this single center randomize...  DDI Clinical Trial
# 9   methods study subjects the university of arkan...  DDI Clinical Trial
# 10  materials and methods reference compounds and ...  DDI Clinical Trial
# 11  methods patients meeting dsm iii r criteria ma...  DDI Clinical Trial
# 12  methods subjects study design twelve male volu...  DDI Clinical Trial
# 13  a healthy 33 year old man treated bupropion sm...            PK Trial
# 14  our subjects ten healthy men age range 21 40ye...  DDI Clinical Trial
# 15  experimental procedures our subjects group six...  DDI Clinical Trial
# 16  methods twelve healthy enrolled formed human a...            PK Trial
# 17  subjects methods this single center open label...  DDI Clinical Trial
# 18  meth ods sub jects after approval research con...  DDI Clinical Trial
# 19  methods this was an open-label, crossover stud...  DDI Clinical Trial
# 20  methods overview study designs this report sum...  DDI Clinical Trial
# 21  methods the clinical protocol was approved by ...  DDI Clinical Trial
# 22  methods and materials this single center rando...            PK Trial
# 23  methods study design results thirteen ages wei...  DDI Clinical Trial
# 24  materials methods after approval obtained medi...  DDI Clinical Trial
# 25  materials methods subjects forty two healthy v...            PK Trial
# 26  materials methods participants participants me...            PK Trial
# 27  methods study entry criteria design subjects d...            PK Trial
# 28  methods subjects a total aged years volunteers...  DDI Clinical Trial
# 29  methods study design ten young healthy volunte...  DDI Clinical Trial
# ..                                                ...                 ...
# 70  methods eighteen healthy subjects six homozygo...  DDI Clinical Trial
# 71  methods study design eight male four female he...  DDI Clinical Trial
# 72  methods this study was conducted at the parke-...  DDI Clinical Trial
# 73  methods subjects patients older years recruite...            PK Trial
# 74  chemicals and reagents\rdextromethorphan hydro...  DDI Clinical Trial
# 75  methods the study carried open randomized cros...  DDI Clinical Trial
# 76  materials and methods the study carried open r...  DDI Clinical Trial
# 77  methods study design eighteen healthy japanese...  DDI Clinical Trial
# 78  methods subjects medications normal psychiatri...  DDI Clinical Trial
# 79  methods following incubation mol l duloxetine ...  DDI Clinical Trial
# 80  materials and methods in-vitro evaluation micr...  DDI Clinical Trial
# 81  methods this study is based upon urine collect...  DDI Clinical Trial
# 82  methods genetic analysis this study approved i...            PK Trial
# 83  participants the study conducted healthy hiv 1...            PK Trial
# 84  methods study population we selected ems pms s...            PK Trial
# 85  materials and methods subjects the subjects in...  DDI Clinical Trial
# 86  methods subjects and ethics. five ultrarapid m...  DDI Clinical Trial
# 87  methods in vitro studies samples liver obtaine...  DDI Clinical Trial
# 88  methods subjects procedures h n desmethyl hocb...            PK Trial
# 89  methods study design this single center random...  DDI Clinical Trial
# 90  methods study design five male seven female vo...  DDI Clinical Trial
# 91  methods design the protocol reviewed approved ...  DDI Clinical Trial
# 92  methods in vitro studies procedures acquisitio...  DDI Clinical Trial
# 93  methods this single center double blind random...  DDI Clinical Trial
# 94  methods n controlled trial healthy male volunt...  DDI Clinical Trial
# 95  methods subjects eighteen healthy male and fem...  DDI Clinical Trial
# 96  methods study design drug analysis this open l...  DDI Clinical Trial
# 97  subjects methods a power calculation used dete...  DDI Clinical Trial
# 98  methods subjects subjects mild hypercholestero...  DDI Clinical Trial
# 99  patients\rin this prospective, non-randomized,...  DDI Clinical Trial
#
#                                   Second Label  \
# 0                       RCT DDI Clinical Trial
# 1                       RCT DDI Clinical Trial
# 2                       RCT DDI Clinical Trial
# 3                       RCT DDI Clinical Trial
# 4   Non-polymorphic enzyme/transport PK Trial
# 5   Non-polymorphic enzyme/transport PK Trial
# 6   Non-polymorphic enzyme/transport PK Trial
# 7                       RCT DDI Clinical Trial
# 8                       RCT DDI Clinical Trial
# 9                       Non RCT Clinical Trial
# 10                      Non RCT Clinical Trial
# 11                      RCT DDI Clinical Trial
# 12                      RCT DDI Clinical Trial
# 13      Polymorphic enzyme/transport PK Trial
# 14                      RCT DDI Clinical Trial
# 15                      RCT DDI Clinical Trial
# 16  Non-polymorphic enzyme/transport PK Trial
# 17                      Non RCT Clinical Trial
# 18                      RCT DDI Clinical Trial
# 19                      Non RCT Clinical Trial
# 20                      RCT DDI Clinical Trial
# 21                      Non RCT Clinical Trial
# 22      Polymorphic enzyme/transport PK Trial
# 23                      RCT DDI Clinical Trial
# 24                      RCT DDI Clinical Trial
# 25      Polymorphic enzyme/transport PK Trial
# 26      Polymorphic enzyme/transport PK Trial
# 27      Polymorphic enzyme/transport PK Trial
# 28                      Non RCT Clinical Trial
# 29                      RCT DDI Clinical Trial
# ..                                         ...
# 70                      RCT DDI Clinical Trial
# 71                      RCT DDI Clinical Trial
# 72                      Non RCT Clinical Trial
# 73      Polymorphic enzyme/transport PK Trial
# 74                      Non RCT Clinical Trial
# 75                      RCT DDI Clinical Trial
# 76                      RCT DDI Clinical Trial
# 77                      RCT DDI Clinical Trial
# 78                      RCT DDI Clinical Trial
# 79                      RCT DDI Clinical Trial
# 80                      Non RCT Clinical Trial
# 81                      Non RCT Clinical Trial
# 82      Polymorphic enzyme/transport PK Trial
# 83      Polymorphic enzyme/transport PK Trial
# 84      Polymorphic enzyme/transport PK Trial
# 85                      Non RCT Clinical Trial
# 86                      Non RCT Clinical Trial
# 87                      RCT DDI Clinical Trial
# 88  Non-polymorphic enzyme/transport PK Trial
# 89                      RCT DDI Clinical Trial
# 90                      RCT DDI Clinical Trial
# 91                      RCT DDI Clinical Trial
# 92                      RCT DDI Clinical Trial
# 93                      RCT DDI Clinical Trial
# 94                      RCT DDI Clinical Trial
# 95                      Non RCT Clinical Trial
# 96                      RCT DDI Clinical Trial
# 97                      RCT DDI Clinical Trial
# 98                      RCT DDI Clinical Trial
# 99                      Non RCT Clinical Trial
#
#                                    Third Label  category_id_1  category_id_2  \
# 0                       RCT DDI Clinical Trial              0              0
# 1                       RCT DDI Clinical Trial              0              0
# 2                       RCT DDI Clinical Trial              0              0
# 3                       RCT DDI Clinical Trial              0              0
# 4   Non-polymorphic enzyme/transport PK Trial               1              1
# 5   Non-polymorphic enzyme/transport PK Trial               1              1
# 6   Non-polymorphic enzyme/transport PK Trial               1              1
# 7                       RCT DDI Clinical Trial              0              0
# 8                       RCT DDI Clinical Trial              0              0
# 9          Non-RCT non-parallel Clinical Trial              0              2
# 10         Non-RCT non-parallel Clinical Trial              0              2
# 11                      RCT DDI Clinical Trial              0              0
# 12                      RCT DDI Clinical Trial              0              0
# 13                         Phenotyped PK Trial              1              3
# 14                      RCT DDI Clinical Trial              0              0
# 15                      RCT DDI Clinical Trial              0              0
# 16  Non-polymorphic enzyme/transport PK Trial               1              1
# 17             Non RCT Parallel Clinical Trial              0              2
# 18                      RCT DDI Clinical Trial              0              0
# 19         Non-RCT non-parallel Clinical Trial              0              2
# 20                      RCT DDI Clinical Trial              0              0
# 21         Non-RCT non-parallel Clinical Trial              0              2
# 22                          Genotyped PK Trial              1              3
# 23                      RCT DDI Clinical Trial              0              0
# 24                      RCT DDI Clinical Trial              0              0
# 25                          Genotyped PK Trial              1              3
# 26                          Genotyped PK Trial              1              3
# 27                         Phenotyped PK Trial              1              3
# 28             Non RCT Parallel Clinical Trial              0              2
# 29                      RCT DDI Clinical Trial              0              0
# ..                                         ...            ...            ...
# 70                      RCT DDI Clinical Trial              0              0
# 71                      RCT DDI Clinical Trial              0              0
# 72         Non-RCT non-parallel Clinical Trial              0              2
# 73                         Phenotyped PK Trial              1              3
# 74         Non-RCT non-parallel Clinical Trial              0              2
# 75                      RCT DDI Clinical Trial              0              0
# 76                      RCT DDI Clinical Trial              0              0
# 77                      RCT DDI Clinical Trial              0              0
# 78                      RCT DDI Clinical Trial              0              0
# 79                      RCT DDI Clinical Trial              0              0
# 80         Non-RCT non-parallel Clinical Trial              0              2
# 81         Non-RCT non-parallel Clinical Trial              0              2
# 82                          Genotyped PK Trial              1              3
# 83                          Genotyped PK Trial              1              3
# 84                         Phenotyped PK Trial              1              3
# 85         Non-RCT non-parallel Clinical Trial              0              2
# 86         Non-RCT non-parallel Clinical Trial              0              2
# 87                      RCT DDI Clinical Trial              0              0
# 88  Non-polymorphic enzyme/transport PK Trial               1              1
# 89                      RCT DDI Clinical Trial              0              0
# 90                      RCT DDI Clinical Trial              0              0
# 91                      RCT DDI Clinical Trial              0              0
# 92                      RCT DDI Clinical Trial              0              0
# 93                      RCT DDI Clinical Trial              0              0
# 94                      RCT DDI Clinical Trial              0              0
# 95         Non-RCT non-parallel Clinical Trial              0              2
# 96                      RCT DDI Clinical Trial              0              0
# 97                      RCT DDI Clinical Trial              0              0
# 98                      RCT DDI Clinical Trial              0              0
# 99         Non-RCT non-parallel Clinical Trial              0              2
#
#     category_id_3
# 0               0
# 1               0
# 2               0
# 3               0
# 4               1
# 5               1
# 6               1
# 7               0
# 8               0
# 9               2
# 10              2
# 11              0
# 12              0
# 13              3
# 14              0
# 15              0
# 16              1
# 17              4
# 18              0
# 19              2
# 20              0
# 21              2
# 22              5
# 23              0
# 24              0
# 25              5
# 26              5
# 27              3
# 28              4
# 29              0
# ..            ...
# 70              0
# 71              0
# 72              2
# 73              3
# 74              2
# 75              0
# 76              0
# 77              0
# 78              0
# 79              0
# 80              2
# 81              2
# 82              5
# 83              5
# 84              3
# 85              2
# 86              2
# 87              0
# 88              1
# 89              0
# 90              0
# 91              0
# 92              0
# 93              0
# 94              0
# 95              2
# 96              0
# 97              0
# 98              0
# 99              2
#
# [100 rows x 9 columns]

# %%
###MOST INFORMATIVE UNIGRAMS###
import pandas as pd
from sklearn.model_selection import train_test_split, cross_val_score, StratifiedKFold, cross_val_predict
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report, confusion_matrix,roc_auc_score, roc_curve, precision_recall_curve
from sklearn.utils import class_weight
import numpy as np 
import matplotlib.pyplot as plt
from sklearn.utils.fixes import signature
from scipy.sparse import hstack
from sklearn.naive_bayes import MultinomialNB
import seaborn as sns
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from collections import defaultdict
from nltk.stem.snowball import SnowballStemmer
from nltk import WordNetLemmatizer, pos_tag, word_tokenize
from nltk.corpus import wordnet
import pickle
from sklearn.pipeline import Pipeline

stemmer = SnowballStemmer('english', ignore_stopwords=False)

class StemmedTfidfVectorizer(TfidfVectorizer):    
    def __init__(self, stemmer, *args, **kwargs):
        super(StemmedTfidfVectorizer, self).__init__(*args, **kwargs)
        self.stemmer = stemmer
        
    def build_analyzer(self):
        analyzer = super(StemmedTfidfVectorizer, self).build_analyzer()
        return lambda doc: (self.stemmer.stem(word) for word in analyzer(doc.replace('\n', ' ')))

#put labels
labels_level_1 = df.category_id_1
labels_level_2 = df.category_id_2
labels_level_3 = df.category_id_3

#Get tfidf from Title. Abstract, Methods Section
text = df['Abstract'] + df['Article Title'] + df['Methods Section']
tfidf = StemmedTfidfVectorizer(stemmer=stemmer, sublinear_tf=True, ngram_range=(1, 1))
features_fit = tfidf.fit(text)
features = features_fit.transform(text)
labels = df.category_id_3

N= 20
for categorize_name, category_id in sorted(category_to_id_3.items()):
    features_chi2 = chi2(features, labels == category_id)
    indices = np.argsort(features_chi2[0])
    feature_names = np.array(tfidf.get_feature_names())[indices]
    unigrams = [v for v in feature_names if len(v.split(' ')) == 1]
    print ("# '{}':".format(categorize_name))
    print ("  . Most correlated unigrams:\n. {}".format('\n. '.join(unigrams[-N:])))
# Out:
# # 'Genotyped PK Trial':
#   . Most correlated bigrams:
# . tc
# . dna
# . pcr
# . snp
# . hmem
# . ampli
# . haplotyp
# . 11187g
# . perphenazin
# . primer
# . genet
# . 388a
# . polymorph
# . 521t
# . slco1b1
# . genotyp
# . cyp3a5
# . allel
# . 1a
# . 1b
# # 'Non RCT Parallel Clinical Trial':
#   . Most correlated bigrams:
# . longest
# . 2inh
# . forum
# . intub
# . outreach
# . icu
# . team
# . dmi
# . mid
# . uoxetin
# . 300mg
# . anaesthesia
# . ekg
# . dissip
# . 1ohmid
# . 4ohmid
# . inh
# . 75mg
# . dmr
# . nfz
# # 'Non-RCT non-parallel Clinical Trial':
#   . Most correlated bigrams:
# . flv
# . mainten
# . 36
# . 30
# . venlafaxin
# . _m
# . 2005
# . _20
# . quetiapin
# . 2000
# . 50
# . placebo
# . concentration_tim
# . ani
# . as
# . from
# . at
# . through
# . until
# . befor
# # 'Non-polymorphic enzyme/transport PK Trial ':
#   . Most correlated bigrams:
# . usp
# . mycot
# . compart
# . lag
# . apixaban
# . hocpz
# . 149
# . dayx
# . eaten
# . uphenazin
# . nonlin
# . cstrip
# . hydroxyclarithromycin
# . cpz
# . formul
# . akaik
# . cuntil
# . fit
# . accumul
# . elder
# # 'Phenotyped PK Trial':
#   . Most correlated bigrams:
# . olunt
# . norway
# . undetect
# . j0
# . didesipramin
# . gmol
# . spigset
# . lsertralin
# . desmethi
# . sulphoridazin
# . uthscsa
# . rom
# . luoxetin
# . sulphoxid
# . mesoridazin
# . olav
# . ereshefski
# . dm
# . debrisoquin
# . dx
# # 'RCT DDI Clinical Trial':
#   . Most correlated bigrams:
# . dsst
# . recal
# . sertralin
# . random
# . phenotyp
# . zolpidem
# . substitut
# . through
# . until
# . ketoconazol
# . blind
# . lovastatin
# . doubl
# . digit
# . crossov
# . triazolam
# . verapamil
# . befor
# . itraconazol
# . placebo
